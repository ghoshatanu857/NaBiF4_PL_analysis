# %%
import plotly.graph_objects as go
import plotly.io as pio
import os
from plotly.subplots import make_subplots


# ============================================================
# --- Figure Template ---
# ============================================================
fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 800,
    'height': 600,
    'xaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False,'zerolinecolor':'white'},
    'yaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False,'zerolinecolor':'white'},
    'font': {'family':'mathjax','size':30}
}

# %% [markdown]
# ### For single power of 975 nm and 1064 nm

# %%
import numpy as np
from scipy.integrate import solve_ivp
import plotly.graph_objects as go

# ------------------------------------------------------------
# --- Simulation parameters ---
# ------------------------------------------------------------
t_max = 3000.0       # total simulation time
dt = 0.5             # time step
t_eval = np.linspace(0, t_max, int(t_max/dt)+1)

# Pulse parameters
laser_on = 200.0
laser_off = 200.0
period = laser_on + laser_off
phase_shift = laser_on  # phase offset for 1064 pulse

# Lifetimes
beta1 = 0.01
beta2 = 0.03

# Coefficients
k_alpha1  = 2
k_alpha1p = 0.05
k_alpha2  = 0.07
k_alpha2p = 0.0001
k_gamma_975 = 0.00001
k_gamma_1064 = 0.017

# Plotly template
fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 1000,
    'height': 450,
    'xaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False, 'zeroline':False},
    'yaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False, 'zeroline':False},
    'font': {'family':'mathjax','size':20}
}

# ------------------------------------------------------------
# --- 1064 nm pulse function ---
# ------------------------------------------------------------
def make_I1064_func(I_1064_peak):
    def I1064(t):
        phase = np.mod(t + phase_shift, period)
        return np.where(phase < laser_on, I_1064_peak, 0.0)
    return I1064

# ------------------------------------------------------------
# --- Run simulation for chosen powers ---
# ------------------------------------------------------------
def run_sim_with_trace(I_975, I_1064_peak):
    I1064 = make_I1064_func(I_1064_peak)

    def I975_func(t):
        return I_975 if np.isscalar(t) else np.full_like(t, I_975)

    def alpha1(t):  return k_alpha1 * I975_func(t) + k_alpha2 * I1064(t)
    def alpha1p(t): return k_alpha1p * I975_func(t) + k_alpha2p * I1064(t)
    def gamma975(t):  return k_gamma_975 * I975_func(t)
    def gamma1064(t): return k_gamma_1064 * I1064(t)

    def rate_equations(t, N):
        N0, N1, N2 = N
        a1  = alpha1(t)
        a1p = alpha1p(t)
        g1  = gamma975(t)
        g2  = gamma1064(t)
        dN0 = -a1*N0 + (beta1+g1+g2)*N1 + beta2*N2
        dN1 = a1*N0 - (a1p+beta1+g1+g2)*N1
        dN2 = a1p*N1 - beta2*N2
        return [dN0, dN1, dN2]

    # Solve ODEs
    sol = solve_ivp(rate_equations, [0, t_max], [1, 0, 0],
                    t_eval=t_eval, atol=1e-9, rtol=1e-7)

    t = sol.t
    N2 = sol.y[2]
    emission = beta2 * N2

    I1064_trace = np.array([I1064(ti) for ti in t])

    return t, emission, I1064_trace

# ------------------------------------------------------------
# --- Manual powers to match experiment ---
# ------------------------------------------------------------
I975_chosen  = 0.09
I1064_chosen = 1.2

PL_t, PL_em, I1064_t = run_sim_with_trace(I975_chosen, I1064_chosen)

# ------------------------------------------------------------
# --- Normalize 1064 nm pulse for visual overlay ---
# ------------------------------------------------------------
I1064_norm = I1064_t / I1064_t.max() * PL_em.max()

# ------------------------------------------------------------
# --- Plot PL + 1064 nm pulse ---
# ------------------------------------------------------------
fig_time = go.Figure()

fig_time.add_trace(go.Scatter(
    x=PL_t, y=PL_em, mode="lines", name="PL emission (β₂N₂)"
))
fig_time.add_trace(go.Scatter(
    x=PL_t, y=I1064_norm, mode="lines", name="1064 nm pulse (scaled)", opacity=0.5
))

fig_time.update_layout(
    template=fig_template,
    xaxis_title="Time",
    yaxis_title="PL Intensity (arb. units)"
)
fig_time.show()

# ------------------------------------------------------------
# --- Pulse-edge quenching with small dt window ---
# ------------------------------------------------------------
pulse_index = 4
dt_sample = dt  # small averaging window

# Detect rising edges of 1064 nm pulse
on_indices = np.where((I1064_t[:-1] == 0) & (I1064_t[1:] > 0))[0]
if pulse_index >= len(on_indices):
    raise ValueError("Not enough pulses in the simulation.")

idx_on = on_indices[pulse_index] + 1

# Detect falling edge of the same pulse
off_candidates = np.where(I1064_t[idx_on:] == 0)[0]
idx_off = idx_on + off_candidates[0]

# Define small dt windows around pulse edges
start_mask = (PL_t >= PL_t[idx_on]) & (PL_t < PL_t[idx_on] + dt_sample)
end_mask   = (PL_t >= PL_t[idx_off] - dt_sample) & (PL_t < PL_t[idx_off])

PL_start = PL_em[start_mask].mean()
PL_end   = PL_em[end_mask].mean()

quench_4th = (PL_start - PL_end) / PL_start * 100

print(f"PL at pulse start (avg): {PL_start:.6e}")
print(f"PL at pulse end   (avg): {PL_end:.6e}")
print(f"Quenching during 4th pulse: {quench_4th:.2f} %")
# Out:
# PL at pulse start (avg): 3.656781e-03
# PL at pulse end   (avg): 3.590793e-03
# Quenching during 4th pulse: 1.80 %

# %%
import numpy as np
from scipy.integrate import solve_ivp
import plotly.graph_objects as go

# ------------------------------------------------------------
# --- Simulation parameters ---
# ------------------------------------------------------------
t_max = 300.0       # total simulation time in ms (enough to cover several pulses)
dt = 1.0            # time step in ms
t_eval = np.arange(0, t_max+dt, dt)

# Pulse parameters (ms)
laser_on = 25.0
laser_off = 25.0
period = laser_on + laser_off
phase_shift = laser_on  # phase offset for 1064 pulse

# Lifetimes (ms)
beta1 = 1/1.0   # generally longer as seen in the excited state of Yb3+
beta2 = 1/7.0  # effective lifetime from both 975 nm and 1064 nm wavelengths

# # Coefficients (1/ms/mW)
# # Chosen roughly to reproduce ~2% quenching for given powers
# k_alpha1  = 5  # 975 nm excitation
# k_alpha1p = 0.04
# k_alpha2  = 0.06  # 1064 nm weak contribution
# k_alpha2p = 0.0005
# k_gamma_975 = 0.00001
# k_gamma_1064 = 0.25

# # # Lifetimes
# # beta1 = 0.01
# # beta2 = 0.03

# # # Coefficients
# # k_alpha1  = 2
# # k_alpha1p = 0.05
# # k_alpha2  = 0.07
# # k_alpha2p = 0.0001
# # k_gamma_975 = 0.00001
# # k_gamma_1064 = 0.017


# Coefficients (1/ms/mW)
# Chosen roughly to reproduce ~2% quenching for given powers
k_alpha1  = 4.8  # 975 nm excitation
k_alpha1p = 0.1
k_alpha2  = 3.9  # 1064 nm weak contribution
k_alpha2p = 0.0002
k_gamma_975 = 2.4
k_gamma_1064 = 3.8

# Plotly template
fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 1000,
    'height': 450,
    'xaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False, 'zeroline':False},
    'yaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False, 'zeroline':False},
    'font': {'family':'mathjax','size':20}
}

# ------------------------------------------------------------
# --- 1064 nm pulse function ---
# ------------------------------------------------------------
def make_I1064_func(I_1064_peak):
    def I1064(t):
        phase = np.mod(t + phase_shift, period)
        return np.where(phase < laser_on, I_1064_peak, 0.0)
    return I1064

# ------------------------------------------------------------
# --- Run simulation for chosen powers ---
# ------------------------------------------------------------
def run_sim_with_trace(I_975, I_1064_peak):
    I1064 = make_I1064_func(I_1064_peak)

    def I975_func(t):
        return I_975 if np.isscalar(t) else np.full_like(t, I_975)

    def alpha1(t):  return k_alpha1 * I975_func(t) + k_alpha2 * I1064(t)
    def alpha1p(t): return k_alpha1p * I975_func(t) + k_alpha2p * I1064(t)
    def gamma975(t):  return k_gamma_975 * I975_func(t)
    def gamma1064(t): return k_gamma_1064 * I1064(t)

    def rate_equations(t, N):
        N0, N1, N2 = N
        a1  = alpha1(t)
        a1p = alpha1p(t)
        g1  = gamma975(t)
        g2  = gamma1064(t)
        dN0 = -a1*N0 + (beta1+g1+g2)*N1 + beta2*N2
        dN1 = a1*N0 - (a1p+beta1+g1+g2)*N1
        dN2 = a1p*N1 - beta2*N2
        return [dN0, dN1, dN2]

    sol = solve_ivp(rate_equations, [0, t_max], [1,0,0],
                    t_eval=t_eval, atol=1e-9, rtol=1e-7)

    t = sol.t
    N2 = sol.y[2]
    emission = beta2 * N2

    I1064_trace = np.array([I1064(ti) for ti in t])
    return t, emission, I1064_trace

# ------------------------------------------------------------
# --- Manual powers in mW to match experiment ---
# ------------------------------------------------------------
I975_chosen  = 19.4
I1064_chosen = 77.0

PL_t, PL_em, I1064_t = run_sim_with_trace(I975_chosen, I1064_chosen)

# ------------------------------------------------------------
# --- Normalize 1064 nm pulse for visual overlay ---
# ------------------------------------------------------------
I1064_norm = I1064_t / I1064_t.max() * PL_em.max()

# ------------------------------------------------------------
# --- Plot PL + 1064 nm pulse ---
# ------------------------------------------------------------
fig_time = go.Figure()
fig_time.add_trace(go.Scatter(x=PL_t, y=PL_em, mode="lines", name="PL emission (β₂N₂)"))
fig_time.add_trace(go.Scatter(x=PL_t, y=I1064_norm, mode="lines", name="1064 nm pulse (scaled)", opacity=0.5))
fig_time.update_layout(template=fig_template, xaxis_title="Time (ms)", yaxis_title="PL Intensity (arb. units)")
fig_time.show()

# ------------------------------------------------------------
# --- Pulse-edge quenching with dt window ---
# ------------------------------------------------------------
pulse_index = 4
dt_sample = dt  # averaging window = 1 ms

# Detect rising edges of 1064 nm pulse
on_indices = np.where((I1064_t[:-1] == 0) & (I1064_t[1:] > 0))[0]
if pulse_index >= len(on_indices):
    raise ValueError("Not enough pulses in the simulation.")

idx_on = on_indices[pulse_index] + 1

# Detect falling edge of the same pulse
off_candidates = np.where(I1064_t[idx_on:] == 0)[0]
idx_off = idx_on + off_candidates[0]

# Small windows around edges
start_mask = (PL_t >= PL_t[idx_on]) & (PL_t < PL_t[idx_on] + dt_sample)
end_mask   = (PL_t >= PL_t[idx_off] - dt_sample) & (PL_t < PL_t[idx_off])

PL_start = PL_em[start_mask].mean()
PL_end   = PL_em[end_mask].mean()

quench_4th = (PL_start - PL_end) / PL_start * 100

print(f"PL at pulse start (avg): {PL_start:.6e}")
print(f"PL at pulse end   (avg): {PL_end:.6e}")
print(f"Quenching during 4th pulse: {quench_4th:.2f} %")

# ------------------------------------------------------------
# --- Zoomed plot around the 4th pulse (quenching visualization)
# ------------------------------------------------------------

# Time window for zoom (a bit before ON and after OFF)
t_zoom_start = PL_t[idx_on]  - 5*dt
t_zoom_end   = PL_t[idx_off] + 5*dt

zoom_mask = (PL_t >= t_zoom_start) & (PL_t <= t_zoom_end)

# --- Y-axis limits: ±1% around quenching ---
y_max = PL_start * 1.01   # 1% above PL at pulse start
y_min = PL_end   * 0.99   # 1% below PL at pulse end

fig_zoom = go.Figure()

# PL emission (zoomed)
fig_zoom.add_trace(go.Scatter(
    x=PL_t[zoom_mask],
    y=PL_em[zoom_mask],
    mode="lines",
    name="PL emission",
    line=dict(width=3)
))

# 1064 nm pulse (scaled, zoomed)
fig_zoom.add_trace(go.Scatter(
    x=PL_t[zoom_mask],
    y=I1064_norm[zoom_mask],
    mode="lines",
    name="1064 nm pulse (scaled)",
    opacity=0.4,
    line=dict(width=3)
))


fig_zoom.update_layout(
    template=fig_template,
    title="Zoomed view of 4th pulse (Quenching evaluation)",
    xaxis_title="Time (ms)",
    yaxis_title="PL Intensity (arb. units)",
    yaxis=dict(
        range=[y_min, y_max],
        zeroline=False
    )
)

fig_zoom.show()
# Out:
# PL at pulse start (avg): 1.283784e-01
# PL at pulse end   (avg): 1.256894e-01
# Quenching during 4th pulse: 2.09 %

# %% [markdown]
# ### Building quenching matrix

# %%
import numpy as np
from scipy.integrate import solve_ivp
from joblib import Parallel, delayed
from tqdm import tqdm
from contextlib import contextmanager

# --- Joblib + tqdm helper ---
@contextmanager
def tqdm_joblib(tqdm_object):
    import joblib
    class TqdmBatchCompletionCallback(joblib.parallel.BatchCompletionCallBack):
        def __call__(self, *args, **kwargs):
            tqdm_object.update(n=self.batch_size)
            return super().__call__(*args, **kwargs)
    old_callback = joblib.parallel.BatchCompletionCallBack
    joblib.parallel.BatchCompletionCallBack = TqdmBatchCompletionCallback
    try:
        yield tqdm_object
    finally:
        joblib.parallel.BatchCompletionCallBack = old_callback
        tqdm_object.close()

# --- Time grid ---
t_max = 3000.0
dt = 0.5
t_eval = np.linspace(0, t_max, int(t_max/dt)+1)

# --- Pulse parameters ---
laser_on = 200.0
laser_off = 200.0
period = laser_on + laser_off
phase_shift = laser_on

def make_I1064_func(I_1064_peak):
    def I1064(t):
        phase = np.mod(t + phase_shift, period)
        return np.where(phase < laser_on, I_1064_peak, 0.0)
    return I1064

# --- Lifetimes ---
beta1 = 1/5.0
beta2 = 1/100.0

# --- Coefficients ---
k_alpha1 = 0.1
k_alpha1p = 0.1
k_alpha2 = 0.001
k_alpha2p = 0.001
k_gamma_975 = 0.001
k_gamma_1064 = 0.2

# --- Simulation function ---
def run_sim(I_975, I_1064_peak):
    I1064 = make_I1064_func(I_1064_peak)
    def I975_func(t):
        return I_975 if np.isscalar(t) else np.full_like(t, I_975)

    def alpha1(t):  return k_alpha1 * I975_func(t) + k_alpha2 * I1064(t)
    def alpha1p(t): return k_alpha1p * I975_func(t) + k_alpha2p * I1064(t)
    def gamma975(t):  return k_gamma_975 * I975_func(t)
    def gamma1064(t): return k_gamma_1064 * I1064(t)

    def rate_equations(t, N):
        N0, N1, N2 = N
        a1  = alpha1(t)
        a1p = alpha1p(t)
        g1  = gamma975(t)
        g2  = gamma1064(t)
        dN0 = -a1*N0 + (beta1+g1+g2)*N1 + beta2*N2
        dN1 = a1*N0 - (a1p+beta1+g1+g2)*N1
        dN2 = a1p*N1 - beta2*N2
        return [dN0, dN1, dN2]

    sol = solve_ivp(rate_equations, [0, t_max], [1,0,0],
                    t_eval=t_eval, atol=1e-9, rtol=1e-7)
    t = sol.t
    N2 = sol.y[2]
    emission = beta2 * N2

    steady_cut = 5 * period
    mask = t >= steady_cut
    phase = np.mod(t + phase_shift, period)
    off_mask = mask & (phase >= laser_on)
    on_mask  = mask & (phase < laser_on)

    if off_mask.sum() == 0 or on_mask.sum() == 0:
        return np.nan

    mean_off = emission[off_mask].mean()
    mean_on  = emission[on_mask].mean()
    quench = (mean_off - mean_on)/mean_off*100
    return quench

# --- Power grids ---
powers_975  = np.geomspace(0.01, 2, 10)
powers_1064 = np.geomspace(0.01, 1.7, 10)

N1 = len(powers_975)
N2 = len(powers_1064)

Q = np.zeros((N2, N1))

# --- Parallel 2D simulation ---
tasks = [(i, j, p975, p1064)
         for j, p1064 in enumerate(powers_1064)
         for i, p975 in enumerate(powers_975)]

with tqdm_joblib(tqdm(total=len(tasks), desc="Computing 2D Quenching Matrix")):
    results = Parallel(n_jobs=-1)(
        delayed(lambda x: (x[0], x[1], run_sim(x[2], x[3])))(task)
        for task in tasks
    )

for i, j, q in results:
    Q[j, i] = q
# Out:
# Computing 2D Quenching Matrix: 100%|█████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.67it/s]

# %%
import plotly.graph_objects as go
import numpy as np

# ------------------------------------------------------------
# Choose fixed powers (nearest indices from grids)
# ------------------------------------------------------------
I975_fixed  = 0.2
I1064_fixed = 0.9

idx_975  = np.argmin(np.abs(powers_975  - I975_fixed))
idx_1064 = np.argmin(np.abs(powers_1064 - I1064_fixed))

# ------------------------------------------------------------
# 1) Quenching vs 975 nm power (fixed 1064 nm)
# ------------------------------------------------------------
fig_q_975 = go.Figure()

fig_q_975.add_trace(
    go.Scatter(
        x=powers_975,
        y=Q[idx_1064, :],
        mode="lines+markers",
        name=f"1064 nm = {powers_1064[idx_1064]:.2f}"
    )
)

fig_q_975.update_layout(
    template=fig_template,
    width = 800,
    height = 450,
    xaxis_title="975 nm Power",
    # yaxis_title="Quenching (%)",
    title="Quenching vs 975 nm Power",
        xaxis=dict(
        zeroline=False,   # remove x=0 line
        showline=True
    ),
    yaxis=dict(
        zeroline=False,   # remove y=0 line
        showline=True
    )
)

fig_q_975.show()

# ------------------------------------------------------------
# 2) Quenching vs 1064 nm power (fixed 975 nm)
# ------------------------------------------------------------
fig_q_1064 = go.Figure()

fig_q_1064.add_trace(
    go.Scatter(
        x=powers_1064,
        y=Q[:, idx_975],
        mode="lines+markers",
        name=f"975 nm = {powers_975[idx_975]:.2f}"
    )
)

fig_q_1064.update_layout(
    template=fig_template,
    width = 800,
    height = 450,
    xaxis_title="1064 nm Power",
    # yaxis_title="Quenching (%)",
    title="Quenching vs 1064 nm Power",
        xaxis=dict(
        zeroline=False,   # remove x=0 line
        showline=True
    ),
    yaxis=dict(
        zeroline=False,   # remove y=0 line
        showline=True
    )
)


fig_q_1064.show()

# %%
import plotly.graph_objects as go

# ============================================================
# --- Figure template ---
# ============================================================
fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 800,
    'height': 600,
    'xaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False},
    'yaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False},
    'font': {'family':'mathjax','size':30}
}

# ============================================================
# --- PLOT 1: Heatmap ---
# ============================================================
fig_hm = go.Figure(data=go.Heatmap(
    x=powers_975,
    y=powers_1064,
    z=Q,
    colorscale="Viridis",
    colorbar_title="Quenching (%)"
))
fig_hm.update_layout(
    template=fig_template,
    width = 1000,
    height = 600,
    title="2D Quenching Map (975 nm vs 1064 nm)",
    xaxis_title="975 nm Power",
    yaxis_title="1064 nm Power"
)
fig_hm.show()

# %%
# # ============================================================
# # --- Plot 2: Quenching vs 1064 nm (fixed 975)
# # ============================================================
# I975_fixed = 19.4
# idx_975 = np.argmin(np.abs(powers_975 - I975_fixed))

# fig_q_1064 = go.Figure()
# fig_q_1064.add_trace(go.Scatter(
#     x=powers_1064,
#     y=Q[:, idx_975],
#     mode="lines+markers",
#     name=f"975 nm = {powers_975[idx_975]:.1f} mW"
# ))
# fig_q_1064.update_layout(
#     template=fig_template,
#     xaxis_title="1064 nm Power (mW)",
#     yaxis_title="Quenching (%)",
#     title="Quenching vs 1064 nm Power"
# )
# # fig_q_1064.show()


# # ============================================================
# # --- Plot 3: 2D Heatmap (975 nm vs 1064 nm)
# # ============================================================
# fig_hm = go.Figure(data=go.Heatmap(
#     x=powers_975,        # 975 nm on x-axis
#     y=powers_1064,       # 1064 nm on y-axis
#     z=Q,                 # Q[j, i] → rows = 1064, cols = 975
#     colorscale="Viridis",
#     colorbar=dict(
#         title="Quenching (%)",
#         titleside="right",
#         thickness=20
#     )
# ))

# fig_hm.update_layout(
#     template=fig_template,
#     width=1000,
#     height=600,
#     title="2D Quenching Map (975 nm vs 1064 nm)",
#     xaxis_title="975 nm Power (mW)",
#     yaxis_title="1064 nm Power (mW)"
# )
# # fig_hm.show()

# %% [markdown]
# ### Matching with experiment

# %% [markdown]
# #### experimental plots

# %%
import pandas as pd
import plotly.graph_objects as go

# ============================================================
# --- Paths to CSV files ---
# ============================================================
lowP_csv = r"D:\Atanu\Atanu_Github\NaBiF4_PL_analysis\NaBiF4_PL_analysis\datas\Oct\7th Oct NaBiF4\face on\good datas\csv_plot_data_lowP\fig2_lowP_signal_vs_975nm.csv"

highP_csv = r"D:\Atanu\Atanu_Github\NaBiF4_PL_analysis\NaBiF4_PL_analysis\datas\Oct\2nd Oct NaBiF4\Percentage Modulation\csv_plot_data\fig2_signal_vs_975nm.csv"

# ============================================================
# --- Load data ---
# ============================================================
df_low = pd.read_csv(lowP_csv)
df_high = pd.read_csv(highP_csv)

# Expected columns:
# Low-P : P975_mW, Signal_percent, Signal_std_percent
# High-P: P975_mW, Signal_percent, Signal_std_percent

# ============================================================
# --- Plot ---
# ============================================================
fig = go.Figure()

# Low-power dataset
fig.add_trace(go.Scatter(
    x=df_low["P975_mW"],
    y=df_low["Signal_percent"],
    error_y=dict(
        type="data",
        array=df_low["Signal_std_percent"],
        visible=True
    ),
    mode="markers",
    marker=dict(
        size=12,
        color="royalblue",
        # symbol="circle"
    ),
    name="Low 975 nm power"
))

# High-power dataset
fig.add_trace(go.Scatter(
    x=df_high["P975_mW"],
    y=df_high["Signal_percent"],
    error_y=dict(
        type="data",
        array=df_high["Signal_std_percent"],
        visible=True
    ),
    mode="markers",
    marker=dict(
        size=12,
        color="crimson",
        # symbol="diamond"
    ),
    name="High 975 nm power"
))

# ============================================================
# --- Layout ---
# ============================================================
fig.update_layout(
    template=fig_template,
    xaxis_title="975 nm Power (mW)",
    # yaxis_title="Signal (%)",
    width=850,
    height=700,
    legend=dict(
        font=dict(size=22),
        borderwidth=0
    )
)

fig.show()

# %%
import pandas as pd
import plotly.graph_objects as go

# ============================================================
# --- Paths to CSV files ---
# ============================================================
lowP_1064_csv = r"D:\Atanu\Atanu_Github\NaBiF4_PL_analysis\NaBiF4_PL_analysis\datas\Oct\7th Oct NaBiF4\face on\good datas\csv_plot_data_lowP\fig1_lowP_signal_vs_1064nm.csv"

highP_1064_csv = r"D:\Atanu\Atanu_Github\NaBiF4_PL_analysis\NaBiF4_PL_analysis\datas\Oct\2nd Oct NaBiF4\Percentage Modulation\csv_plot_data\fig1_signal_vs_1064nm.csv"

# ============================================================
# --- Load data ---
# ============================================================
df_low_1064  = pd.read_csv(lowP_1064_csv)
df_high_1064 = pd.read_csv(highP_1064_csv)

# Expected columns:
# P1064_mW, Signal_percent, Signal_std_percent

# ============================================================
# --- Plot ---
# ============================================================
fig = go.Figure()

# Low-power dataset
fig.add_trace(go.Scatter(
    x=df_low_1064["P1064_mW"],
    y=df_low_1064["Signal_percent"],
    error_y=dict(
        type="data",
        array=df_low_1064["Signal_std_percent"],
        visible=True
    ),
    mode="markers",
    marker=dict(
        size=12,
        color="royalblue",
        symbol="circle-open"   # open circles (optional but nice)
    ),
    name="Low 1064 nm power"
))

# High-power dataset
fig.add_trace(go.Scatter(
    x=df_high_1064["P1064_mW"],
    y=df_high_1064["Signal_percent"],
    error_y=dict(
        type="data",
        array=df_high_1064["Signal_std_percent"],
        visible=True
    ),
    mode="markers",
    marker=dict(
        size=12,
        color="crimson",
        symbol="circle-open"
    ),
    name="High 1064 nm power"
))

# ============================================================
# --- Layout ---
# ============================================================
fig.update_layout(
    template=fig_template,
    xaxis_title="1064 nm Power (mW)",
    # yaxis_title="Signal (%)",
    width=850,
    height=700,
    legend=dict(
        font=dict(size=22),
        borderwidth=0
    )
)

fig.show()

# %% [markdown]
# #### simulation

# %%
import numpy as np
from scipy.integrate import solve_ivp
from joblib import Parallel, delayed
from tqdm import tqdm
from contextlib import contextmanager
import plotly.graph_objects as go
from plotly.subplots import make_subplots


# ============================================================
# --- Joblib + tqdm helper (same as first code)
# ============================================================
@contextmanager
def tqdm_joblib(tqdm_object):
    import joblib
    class TqdmBatchCompletionCallback(joblib.parallel.BatchCompletionCallBack):
        def __call__(self, *args, **kwargs):
            tqdm_object.update(n=self.batch_size)
            return super().__call__(*args, **kwargs)
    old_callback = joblib.parallel.BatchCompletionCallBack
    joblib.parallel.BatchCompletionCallBack = TqdmBatchCompletionCallback
    try:
        yield tqdm_object
    finally:
        joblib.parallel.BatchCompletionCallBack = old_callback
        tqdm_object.close()

# ============================================================
# --- Simulation parameters
# ============================================================
t_max = 300.0
dt = 1.0
t_eval = np.arange(0, t_max + dt, dt)

laser_on = 25.0
laser_off = 25.0
period = laser_on + laser_off
phase_shift = laser_on

# # Lifetimes (ms)
# # beta1 = 1/0.5   # generally longer as seen in the excited state of Yb3+
# beta2 = 1/0.2  # effective lifetime from both 975 nm and 1064 nm wavelengths
# beta1 = 0.0  # effective lifetime from both 975 nm and 1064 nm wavelengths

# # # Coefficients (1/ms/mW)
# # k_alpha1  = 0.02  
# # k_alpha1p = 0.014
# # k_alpha2  = 0.005
# # k_alpha2p = 0.00001
# # k_gamma_975 = 0.0005
# # k_gamma_1064 = 0.004058

# # # Coefficients (1/ms/mW)
# # k_alpha1  = 0.02  
# # k_alpha1p = 0.00655
# # k_alpha2  = 0.01
# # k_alpha2p = 0.00001
# # k_gamma_975 = 0.0005
# # k_gamma_1064 = 0.004058


# # Coefficients (1/ms/mW)
# k_alpha1  = 0.016    
# k_alpha1p = 0.0165
# k_alpha2  = 0.0041
# k_alpha2p = 0.0000105
# k_gamma_975 = 0.0032
# k_gamma_1064 = 0.0055




# Lifetimes (ms)
# beta1 = 1/0.5   # generally longer as seen in the excited state of Yb3+
beta2 = 1/0.2  # effective lifetime from both 975 nm and 1064 nm wavelengths
beta1 = 1/0.5  # effective lifetime from both 975 nm and 1064 nm wavelengths


# # Coefficients (1/ms/mW)
# k_alpha1  = 0.3    
# k_alpha1p = 0.22
# k_alpha2  = 0.0011
# k_alpha2p = 0.00001
# k_gamma_975 = 0.02
# k_gamma_1064 = 0.01


# Coefficients (1/ms/mW)
k_alpha1  = 0.014
k_alpha1p = 0.016
k_alpha2  = 0.0000045
k_alpha2p = 0.000007
k_gamma_975 = 0.039
k_gamma_1064 = 0.001

# ============================================================
# --- Plotly template
# ============================================================
fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 800,
    'height': 450,
    'xaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'showline':True,'zeroline':False},
    'yaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'showline':True,'zeroline':False},
    'font': {'family':'mathjax','size':20}
}

# ============================================================
# --- 1064 nm pulse
# ============================================================
def make_I1064_func(I_1064_peak):
    def I1064(t):
        phase = np.mod(t + phase_shift, period)
        return np.where(phase < laser_on, I_1064_peak, 0.0)
    return I1064

# ============================================================
# --- Single simulation → quenching
# ============================================================
def run_sim_quench(I_975, I_1064_peak, pulse_index=4):
    I1064 = make_I1064_func(I_1064_peak)

    def I975_func(t):
        return I_975 if np.isscalar(t) else np.full_like(t, I_975)

    def alpha1(t):  return k_alpha1 * I975_func(t) + k_alpha2 * I1064(t)
    def alpha1p(t): return k_alpha1p * I975_func(t) + k_alpha2p * I1064(t)
    def gamma975(t):  return k_gamma_975 * I975_func(t)
    def gamma1064(t): return k_gamma_1064 * I1064(t)

    def rate_equations(t, N):
        N0, N1, N2 = N
        a1  = alpha1(t)
        a1p = alpha1p(t)
        g1  = gamma975(t)
        g2  = gamma1064(t)
        dN0 = -a1*N0 + (beta1+g1+g2)*N1 + beta2*N2
        dN1 = a1*N0 - (a1p+beta1+g1+g2)*N1
        dN2 = a1p*N1 - beta2*N2
        return [dN0, dN1, dN2]

    sol = solve_ivp(rate_equations, [0, t_max], [1,0,0],
                    t_eval=t_eval, atol=1e-9, rtol=1e-7)

    t = sol.t
    emission = beta2 * sol.y[2]
    I1064_t = np.array([I1064(ti) for ti in t])

    # Detect rising edges
    on_indices = np.where((I1064_t[:-1] == 0) & (I1064_t[1:] > 0))[0]
    if pulse_index >= len(on_indices):
        return np.nan

    idx_on = on_indices[pulse_index] + 1
    idx_off = idx_on + np.where(I1064_t[idx_on:] == 0)[0][0]

    start_mask = (t >= t[idx_on]) & (t < t[idx_on] + dt)
    end_mask   = (t >= t[idx_off] - dt) & (t < t[idx_off])

    PL_start = emission[start_mask].mean()
    PL_end   = emission[end_mask].mean()

    return (PL_start - PL_end) / PL_start * 100

# %% [markdown]
# #### combined

# %% [markdown]
# ##### Quenching

# %%
# ------------------------------------------------------------
# --- Run simulation for chosen powers ---
# ------------------------------------------------------------
def run_sim_with_trace(I_975, I_1064_peak):
    I1064 = make_I1064_func(I_1064_peak)

    def I975_func(t):
        return I_975 if np.isscalar(t) else np.full_like(t, I_975)

    def alpha1(t):  return k_alpha1 * I975_func(t) + k_alpha2 * I1064(t)
    def alpha1p(t): return k_alpha1p * I975_func(t) + k_alpha2p * I1064(t)
    def gamma975(t):  return k_gamma_975 * I975_func(t)
    def gamma1064(t): return k_gamma_1064 * I1064(t)

    def rate_equations(t, N):
        N0, N1, N2 = N
        a1  = alpha1(t)
        a1p = alpha1p(t)
        g1  = gamma975(t)
        g2  = gamma1064(t)
        dN0 = -a1*N0 + (beta1+g1+g2)*N1 + beta2*N2
        dN1 = a1*N0 - (a1p+beta1+g1+g2)*N1
        dN2 = a1p*N1 - beta2*N2
        return [dN0, dN1, dN2]

    sol = solve_ivp(rate_equations, [0, t_max], [1,0,0],
                    t_eval=t_eval, atol=1e-9, rtol=1e-7)

    t = sol.t
    N2 = sol.y[2]
    emission = beta2 * N2

    I1064_trace = np.array([I1064(ti) for ti in t])
    return t, emission, I1064_trace


# ------------------------------------------------------------
# --- Manual powers in mW to match experiment ---
# ------------------------------------------------------------
I975_chosen  = 19.4
I1064_chosen = 77.0

PL_t, PL_em, I1064_t = run_sim_with_trace(I975_chosen, I1064_chosen)

# ------------------------------------------------------------
# --- Normalize 1064 nm pulse for visual overlay ---
# ------------------------------------------------------------
I1064_norm = I1064_t / I1064_t.max() * PL_em.max()

# ------------------------------------------------------------
# --- Plot PL + 1064 nm pulse ---
# ------------------------------------------------------------
fig_time = go.Figure()
fig_time.add_trace(go.Scatter(x=PL_t, y=PL_em, mode="lines", name="PL emission (β₂N₂)"))
fig_time.add_trace(go.Scatter(x=PL_t, y=I1064_norm, mode="lines", name="1064 nm pulse (scaled)", opacity=0.5))
fig_time.update_layout(template=fig_template, xaxis_title="Time (ms)", yaxis_title="PL Intensity (arb. units)")
fig_time.show()

# ------------------------------------------------------------
# --- Pulse-edge quenching with dt window ---
# ------------------------------------------------------------
pulse_index = 4
dt_sample = dt  # averaging window = 1 ms

# Detect rising edges of 1064 nm pulse
on_indices = np.where((I1064_t[:-1] == 0) & (I1064_t[1:] > 0))[0]
if pulse_index >= len(on_indices):
    raise ValueError("Not enough pulses in the simulation.")

idx_on = on_indices[pulse_index] + 1

# Detect falling edge of the same pulse
off_candidates = np.where(I1064_t[idx_on:] == 0)[0]
idx_off = idx_on + off_candidates[0]

# Small windows around edges
start_mask = (PL_t >= PL_t[idx_on]) & (PL_t < PL_t[idx_on] + dt_sample)
end_mask   = (PL_t >= PL_t[idx_off] - dt_sample) & (PL_t < PL_t[idx_off])

PL_start = PL_em[start_mask].mean()
PL_end   = PL_em[end_mask].mean()

quench_4th = (PL_start - PL_end) / PL_start * 100

print(f"PL at pulse start (avg): {PL_start:.6e}")
print(f"PL at pulse end   (avg): {PL_end:.6e}")
print(f"Quenching during 4th pulse: {quench_4th:.2f} %")


# ------------------------------------------------------------
# --- Zoomed plot around the 4th pulse (quenching visualization)
# ------------------------------------------------------------

# Time window for zoom (a bit before ON and after OFF)
t_zoom_start = PL_t[idx_on]  - 5*dt
t_zoom_end   = PL_t[idx_off] + 5*dt

zoom_mask = (PL_t >= t_zoom_start) & (PL_t <= t_zoom_end)

# --- Y-axis limits: ±1% around quenching ---
y_max = PL_start * 1.01   # 1% above PL at pulse start
y_min = PL_end   * 0.99   # 1% below PL at pulse end

fig_zoom = go.Figure()

# PL emission (zoomed)
fig_zoom.add_trace(go.Scatter(
    x=PL_t[zoom_mask],
    y=PL_em[zoom_mask],
    mode="lines",
    name="PL emission",
    line=dict(width=3)
))

# 1064 nm pulse (scaled, zoomed)
fig_zoom.add_trace(go.Scatter(
    x=PL_t[zoom_mask],
    y=I1064_norm[zoom_mask],
    mode="lines",
    name="1064 nm pulse (scaled)",
    opacity=0.4,
    line=dict(width=3)
))


fig_zoom.update_layout(
    template=fig_template,
    title="Zoomed view of 4th pulse (Quenching evaluation)",
    xaxis_title="Time (ms)",
    yaxis_title="PL Intensity (arb. units)",
    yaxis=dict(
        range=[y_min, y_max],
        zeroline=False
    )
)

fig_zoom.show()

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# ============================
# --- Experimental file path
# ============================
exp_path = r"D:\Atanu\Atanu_Github\NaBiF4_PL_analysis\NaBiF4_PL_analysis\datas\Oct\2nd Oct NaBiF4\Percentage Modulation\1064nm_3.86mA\1064nm_3.86mW_20Hz_975nm_80mW.txt"

# ============================
# --- Load experimental data
# ============================
df_exp = pd.read_csv(exp_path, sep="\t")

# Convert time from ps to ms
exp_time_ms = df_exp["Time (ps)"].to_numpy() * 1e-9
exp_counts  = df_exp["Counts per bin"].to_numpy()

# ============================
# --- Zoom window
# ============================
x1_ms, x2_ms = 24.7, 50.0

# ============================
# --- Simulated data (existing variables)
# ============================
sim_time_ms = PL_t
sim_em = PL_em

# crop simulated only in the zoom window
sim_mask = (sim_time_ms >= x1_ms) & (sim_time_ms <= x2_ms)
sim_time_ms_zoom = sim_time_ms[sim_mask]
sim_em_zoom = sim_em[sim_mask]

# ===========================
# --- Rescale simulation to match experiment
# ===========================
sim_em_scaled = sim_em_zoom*np.max(exp_counts)/np.max(sim_em_zoom)

# ============================
# --- Plot
# ============================
fig_zoom = go.Figure()

# Experimental (full range)
fig_zoom.add_trace(go.Scatter(
    x=exp_time_ms,
    y=exp_counts,
    mode="markers",
    name="Experimental",
    marker=dict(size=4, color="black"),
    opacity=0.6
))

# Simulated (ONLY in zoom window)
fig_zoom.add_trace(go.Scatter(
    x=sim_time_ms_zoom,
    y=sim_em_scaled,
    mode="lines",
    name="Simulated (scaled)",
    line=dict(width=3, color="crimson")
))

fig_zoom.update_layout(
    template=fig_template,
    title="Zoomed view of 4th pulse (Quenching evaluation)",
    xaxis_title="Time (ms)",
    yaxis_title="Counts (arb. units)",
    yaxis=dict(zeroline=False)
)

fig_zoom.show()

# %% [markdown]
# ##### for 975 nm

# %%
# ============================================================
# --- Power grids (EXPERIMENTAL)
# ============================================================
powers_975  = np.geomspace(0.1, 58.0, 200)
# powers_975  = np.concatenate((df_low["P975_mW"],df_high["P975_mW"]))
# powers_1064 = np.linspace(10.0, 77.0, 5)
powers_1064 = np.array([77.0])

N1 = len(powers_975)
N2 = len(powers_1064)

Q_975 = np.zeros((N2, N1))

# ============================================================
# --- Parallel computation
# ============================================================
tasks = [(i, j, p975, p1064)
         for j, p1064 in enumerate(powers_1064)
         for i, p975 in enumerate(powers_975)]

with tqdm_joblib(tqdm(total=len(tasks), desc="Computing Quenching Matrix")):
    results = Parallel(n_jobs=-1)(
        delayed(lambda x: (x[0], x[1], run_sim_quench(x[2], x[3])))(task)
        for task in tasks
    )

for i, j, q in results:
    Q_975[j, i] = q
# Out:
# Computing Quenching Matrix: 100%|████████████████████████████████████████████████████| 200/200 [00:18<00:00, 10.73it/s]

# %%
powers_975, Q_975, np.concatenate((y_low,y_high))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 powers_975, Q_975, np.concatenate((y_low,y_high))
#
# NameError: name 'y_low' is not defined

# %%
I1064_fixed = 77.0
idx_1064 = np.argmin(np.abs(powers_1064 - I1064_fixed))
xdata = powers_975
ydata = Q_975[idx_1064, :]

x_left  = [np.min(xdata)*0.5, 1.2]
x_right = [15, np.max(xdata)]

y_pos = [0.3, np.nanmax(ydata) * 1.1]
y_neg = [np.nanmin(ydata) * 1.1, 5]

# -----------------------------
# Subplots (hidden seams)
# -----------------------------
fig = make_subplots(
    rows=2, cols=2,
    shared_xaxes=True,
    shared_yaxes=True,
    horizontal_spacing=0.05,
    vertical_spacing=0.05
)


def add_trace(row, col, xmask, ymask):
    mask = xmask & ymask
    x=xdata[mask]
    y=ydata[mask]
    if row==2 and col==2:
        x = None
        y = None

    if row==1 and col==1:
        x = None
        y = None
        
    fig.add_trace(
        go.Scatter(
            x=x,
            y=y,
            mode="lines",
            marker=dict(size=15,symbol="circle-open",line=dict(width=3) ),
            line=dict(width=4),
            showlegend=False
        ),
        row=row, col=col
    )

def add_exp_trace(row, col, x, y, yerr, xmask, ymask, color, name):
    mask = xmask & ymask
    x_plot = x[mask]
    y_plot = y[mask]
    yerr_plot = yerr[mask]

    if row == 2 and col == 2:
        x_plot = None
        y_plot = None
        yerr_plot = None

    fig.add_trace(
        go.Scatter(
            x=x_plot,
            y=y_plot,
            error_y=dict(
                type="data",
                array=yerr_plot,
                visible=True
            ),
            mode="markers",
            marker=dict(size=15, color=color),
            showlegend=False,
            name=name
        ),
        row=row, col=col
    )



x_left_mask  = xdata <= x_left[1]
x_right_mask = xdata >= x_right[0]

y_pos_mask = ydata >= y_pos[0]
y_neg_mask = ydata <= y_neg[1]


add_trace(1, 1, x_left_mask,  y_pos_mask)
add_trace(1, 2, x_right_mask, y_pos_mask)
add_trace(2, 1, x_left_mask,  y_neg_mask)
add_trace(2, 2, x_right_mask, y_neg_mask)




x_low  = df_low["P975_mW"].to_numpy()
y_low  = df_low["Signal_percent"].to_numpy()
yerr_low = df_low["Signal_std_percent"].to_numpy()

x_high = df_high["P975_mW"].to_numpy()
y_high = df_high["Signal_percent"].to_numpy()
yerr_high = df_high["Signal_std_percent"].to_numpy()


x_left_mask_low   = x_low  <= x_left[1]
x_right_mask_low  = x_low  >= x_right[0]

x_left_mask_high  = x_high <= x_left[1]
x_right_mask_high = x_high >= x_right[0]

y_pos_mask_low  = y_low  >= y_pos[0]
y_neg_mask_low  = y_low  <= y_neg[1]

y_pos_mask_high = y_high >= y_pos[0]
y_neg_mask_high = y_high <= y_neg[1]

add_exp_trace(1, 1, x_low, y_low, yerr_low,
              x_left_mask_low, y_pos_mask_low,
              color="royalblue", name="Low P")

add_exp_trace(1, 2, x_low, y_low, yerr_low,
              x_right_mask_low, y_pos_mask_low,
              color="royalblue", name="Low P")

add_exp_trace(2, 1, x_low, y_low, yerr_low,
              x_left_mask_low, y_neg_mask_low,
              color="royalblue", name="Low P")

add_exp_trace(2, 2, x_low, y_low, yerr_low,
              x_right_mask_low, y_neg_mask_low,
              color="royalblue", name="Low P")


add_exp_trace(1, 1, x_high, y_high, yerr_high,
              x_left_mask_high, y_pos_mask_high,
              color="crimson", name="High P")

add_exp_trace(1, 2, x_high, y_high, yerr_high,
              x_right_mask_high, y_pos_mask_high,
              color="crimson", name="High P")

add_exp_trace(2, 1, x_high, y_high, yerr_high,
              x_left_mask_high, y_neg_mask_high,
              color="crimson", name="High P")

add_exp_trace(2, 2, x_high, y_high, yerr_high,
              x_right_mask_high, y_neg_mask_high,
              color="crimson", name="High P")


# -----------------------------
# Axis ranges
# -----------------------------
fig.update_xaxes(range=x_left,  row=1, col=1)
fig.update_xaxes(range=x_right, row=1, col=2)
fig.update_xaxes(range=x_left,  row=2, col=1)
fig.update_xaxes(range=x_right, row=2, col=2)

fig.update_yaxes(range=y_pos, row=1, col=1)
fig.update_yaxes(range=y_pos, row=1, col=2)
fig.update_yaxes(range=y_neg, row=2, col=1)
fig.update_yaxes(range=y_neg, row=2, col=2)

# -----------------------------
# Remove all axis lines for ALL subplots
# -----------------------------
for r in [1, 2]:
    for c in [1, 2]:
        fig.update_xaxes(showline=False, 
                         # showgrid=False, 
                         zeroline=True, 
                         ticks="",
                         row=r, col=c)
        fig.update_yaxes(showline=False, 
                         # showgrid=False, 
                         zeroline=True, 
                         ticks="",
                         row=r, col=c)

# -----------------------------
# Labels & layout
# -----------------------------
fig.update_layout(
    template=fig_template,
    # title="Quenching vs 975 nm Power",
    height=650,
    width=800,
    showlegend=False
)

fig.update_xaxes(title_text="975 nm Power (mW)", row=2, col=2)
# fig.update_yaxes(title_text="Quenching (%)", row=1, col=1)

# # -----------------------------
# # Break markers
# # -----------------------------
# fig.add_annotation(
#     text="//", xref="paper", yref="paper",
#     x=0.50, y=0.02, showarrow=False, font=dict(size=22)
# )

# fig.add_annotation(
#     text="//", xref="paper", yref="paper",
#     x=0.02, y=0.50, showarrow=False, font=dict(size=22)
# )
# for r in [1, 2]:
#     for c in [1, 2]:
#         fig.update_xaxes(
#             zeroline=False,
#             # showline=False,   
#             row=r,
#             col=c
#         )

for r in [1, 2]:
    for c in [1, 2]:
        fig.update_xaxes(
            showgrid=True,
            gridcolor="rgba(0,0,0,0.25)",  # darker grid
            gridwidth=1.5,                # thicker lines
            row=r, col=c
        )
        fig.update_yaxes(
            showgrid=True,
            gridcolor="rgba(0,0,0,0.25)",
            gridwidth=1.5,
            row=r, col=c
        )

fig.show()


# ============================================================
# --- Save figure ---
# ============================================================
output_fig_folder = r"D:\Atanu\Atanu_Github\NaBiF4_PL_analysis\NaBiF4_PL_analysis\figures in paper"
os.makedirs(output_fig_folder, exist_ok=True)
out_path = os.path.join(output_fig_folder, "975nm_quenching_statistics.png")
pio.write_image(fig, out_path, scale=4)
print("Saved figure:", out_path)
# Out:
# Saved figure: D:\Atanu\Atanu_Github\NaBiF4_PL_analysis\NaBiF4_PL_analysis\figures in paper\975nm_quenching_statistics.png

# %%
# import pandas as pd

# # Create a dataframe
# df = pd.DataFrame({
#     "x_experimental": x_high,
#     "y_experimental": y_high,
#     "y_simulation": ydata[-8:]
# })

# # Specify the path where you want to save the file
# file_path = r"D:\data.xlsx"   # change this path

# # Save to Excel
# df.to_excel(file_path, index=False)

# print("File saved successfully.")
# xdata,ydata,x_high, y_high

# %% [markdown]
# ##### for 1064 nm

# %%
import numpy as np
from joblib import Parallel, delayed
from tqdm import tqdm

# ============================================================
# --- Power grids (EXPERIMENTAL)
# ============================================================
powers_975 = np.array([0.1436, 19.435])

powers_1064_low  = df_low_1064["P1064_mW"].to_numpy()
powers_1064_high = df_high_1064["P1064_mW"].to_numpy()

N2_low  = len(powers_1064_low)
N2_high = len(powers_1064_high)

# ============================================================
# --- Allocate output arrays
# ============================================================
Q_1064_low  = np.zeros(N2_low)
Q_1064_high = np.zeros(N2_high)

# ============================================================
# --- LOW 1064 nm data → powers_975[0]
# ============================================================
tasks_low = [
    (j, powers_975[0], p1064)
    for j, p1064 in enumerate(powers_1064_low)
]

with tqdm_joblib(tqdm(total=len(tasks_low), desc="Computing Q_1064_low")):
    results_low = Parallel(n_jobs=-1)(
        delayed(lambda x: (x[0], run_sim_quench(x[1], x[2])))(task)
        for task in tasks_low
    )

for j, q in results_low:
    Q_1064_low[j] = q

# ============================================================
# --- HIGH 1064 nm data → powers_975[1]
# ============================================================
tasks_high = [
    (j, powers_975[1], p1064)
    for j, p1064 in enumerate(powers_1064_high)
]

with tqdm_joblib(tqdm(total=len(tasks_high), desc="Computing Q_1064_high")):
    results_high = Parallel(n_jobs=-1)(
        delayed(lambda x: (x[0], run_sim_quench(x[1], x[2])))(task)
        for task in tasks_high
    )

for j, q in results_high:
    Q_1064_high[j] = q

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import numpy as np

# ============================================================
# --- Y ranges (broken Y) ---
# ============================================================
y_pos = [0, 2.5]
y_neg = [-200, -20]

# ============================================================
# --- Create subplots ---
# ============================================================
fig = make_subplots(
    rows=2, cols=2,
    shared_xaxes=True,   # IMPORTANT: different x grids
    shared_yaxes=True,
    vertical_spacing=0.05,
    horizontal_spacing=0.05
)

# ============================================================
# --- Simulated data (SEPARATED correctly) ---
# ============================================================
xdata_left  = df_low_1064["P1064_mW"].to_numpy()
xdata_right = df_high_1064["P1064_mW"].to_numpy()

ydata_left  = Q_1064_low     # LEFT column
ydata_right = Q_1064_high    # RIGHT column

# ============================================================
# --- Simulated trace helper ---
# ============================================================
def add_sim_trace(row, col, xdata, ydata, ymask):
    x = xdata[ymask]
    y = ydata[ymask]

    if row == 2 and col == 2:
        x = None
        y = None

    fig.add_trace(
        go.Scatter(
            x=x,
            y=y,
            mode="markers",
            marker=dict(
                size=15,
                symbol="circle-open",
                line=dict(width=3)
            ),
            showlegend=False
        ),
        row=row, col=col
    )

# ============================================================
# --- Y masks (simulation) ---
# ============================================================
y_pos_mask_left  = (ydata_left  >= y_pos[0]) & (ydata_left  <= y_pos[1])
y_neg_mask_left  = (ydata_left  >= y_neg[0]) & (ydata_left  <= y_neg[1])

y_pos_mask_right = (ydata_right >= y_pos[0]) & (ydata_right <= y_pos[1])
y_neg_mask_right = (ydata_right >= y_neg[0]) & (ydata_right <= y_neg[1])

# ============================================================
# --- Add simulated traces ---
# ============================================================
# LEFT column → Q_1064_low
add_sim_trace(1, 1, xdata_left,  ydata_left,  y_pos_mask_left)
add_sim_trace(2, 1, xdata_left,  ydata_left,  y_neg_mask_left)

# RIGHT column → Q_1064_high
add_sim_trace(1, 2, xdata_right, ydata_right, y_pos_mask_right)
add_sim_trace(2, 2, xdata_right, ydata_right, y_neg_mask_right)

# ============================================================
# --- Experimental trace helper ---
# ============================================================
def add_exp_trace(row, col, x, y, yerr, ymask, color):
    x_plot = x[ymask]
    y_plot = y[ymask]
    yerr_plot = yerr[ymask]

    if row == 2 and col == 2:
        x_plot = None
        y_plot = None
        yerr_plot = None

    fig.add_trace(
        go.Scatter(
            x=x_plot,
            y=y_plot,
            error_y=dict(
                type="data",
                array=yerr_plot,
                visible=True
            ),
            mode="markers",
            marker=dict(size=15, color=color),
            showlegend=False
        ),
        row=row, col=col
    )

# ============================================================
# --- Experimental data ---
# ============================================================
x_low   = df_low_1064["P1064_mW"].to_numpy()
y_low   = df_low_1064["Signal_percent"].to_numpy()
yerr_low = df_low_1064["Signal_std_percent"].to_numpy()

x_high   = df_high_1064["P1064_mW"].to_numpy()
y_high   = df_high_1064["Signal_percent"].to_numpy()
yerr_high = df_high_1064["Signal_std_percent"].to_numpy()

# ============================================================
# --- Experimental Y masks ---
# ============================================================
y_pos_mask_low  = (y_low  >= y_pos[0]) & (y_low  <= y_pos[1])
y_neg_mask_low  = (y_low  >= y_neg[0]) & (y_low  <= y_neg[1])

y_pos_mask_high = (y_high >= y_pos[0]) & (y_high <= y_pos[1])
y_neg_mask_high = (y_high >= y_neg[0]) & (y_high <= y_neg[1])

# ============================================================
# --- Add experimental traces ---
# ============================================================
# LEFT (low P)
add_exp_trace(1, 1, x_low,  y_low,  yerr_low,  y_pos_mask_low,  "royalblue")
add_exp_trace(2, 1, x_low,  y_low,  yerr_low,  y_neg_mask_low,  "royalblue")

# RIGHT (high P)
add_exp_trace(1, 2, x_high, y_high, yerr_high, y_pos_mask_high, "crimson")
add_exp_trace(2, 2, x_high, y_high, yerr_high, y_neg_mask_high, "crimson")

# ============================================================
# --- Axis ranges ---
# ============================================================
fig.update_yaxes(range=y_pos, row=1, col=1)
fig.update_yaxes(range=y_pos, row=1, col=2)

fig.update_yaxes(range=y_neg, row=2, col=1)
fig.update_yaxes(range=y_neg, row=2, col=2)

fig.update_xaxes(title_text="1064 nm Power (mW)", row=2, col=1)
fig.update_xaxes(title_text="1064 nm Power (mW)", row=2, col=2)

# ============================================================
# --- Styling ---
# ============================================================
for r in [1, 2]:
    for c in [1, 2]:
        fig.update_xaxes(showline=False, ticks="", zeroline=False, row=r, col=c)
        fig.update_yaxes(showline=False, ticks="", zeroline=False, row=r, col=c)

# ============================================================
# --- Layout ---
# ============================================================
fig.update_layout(
    template=fig_template,
    height=650,
    width=900,
    showlegend=False
)

fig.show()

# %% [markdown]
# ##### Histogram

# %%
# ============================================================
# --- Power grids (EXPERIMENTAL)
# ============================================================
powers_975  = df_high["P975_mW"]
powers_1064 = df_high_1064["P1064_mW"]

N1 = len(powers_975)
N2 = len(powers_1064)

Q = np.zeros((N2, N1))

# ============================================================
# --- Parallel computation
# ============================================================
tasks = [(i, j, p975, p1064)
         for j, p1064 in enumerate(powers_1064)
         for i, p975 in enumerate(powers_975)]

with tqdm_joblib(tqdm(total=len(tasks), desc="Computing Quenching Matrix")):
    results = Parallel(n_jobs=-1)(
        delayed(lambda x: (x[0], x[1], run_sim_quench(x[2], x[3])))(task)
        for task in tasks
    )

for i, j, q in results:
    Q[j, i] = q
# Out:
# Computing Quenching Matrix: 100%|██████████████████████████████████████████████████████| 56/56 [00:03<00:00, 15.73it/s]

# %%
Q.shape
# Out:
# (7, 8)

# %%
# ============================================================
# --- Heatmap (pixelated, no smoothing) ---
# ============================================================
fig = go.Figure()

fig.add_trace(
    go.Heatmap(
        x=powers_975,
        y=powers_1064,
        z=Q,
        coloraxis="coloraxis"
    )
)

fig.update_layout(
    template=fig_template,
    xaxis_title="975 nm Power (mW)",
    yaxis_title="1064 nm Power (mW)",
    width=800,
    height=650,
    coloraxis=dict(
        colorscale="Viridis",
        cmin=np.nanmin(Q),
        cmax=np.nanmax(Q),
        showscale=True
    )
)

fig.show()


# ============================================================
# --- Save figure ---
# ============================================================
output_fig_folder = r"D:\Atanu\NaBiF4_PL_analysis\NaBiF4_PL_analysis\NaBiF4_PL_analysis\figures in paper"
os.makedirs(output_fig_folder, exist_ok=True)
out_path = os.path.join(output_fig_folder, "heatmap_simulated.png")
pio.write_image(fig, out_path, scale=4)
print("Saved figure:", out_path)
# Out:
# Saved figure: D:\Atanu\NaBiF4_PL_analysis\NaBiF4_PL_analysis\NaBiF4_PL_analysis\figures in paper\heatmap_simulated.png

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# ============================================================
# --- Load heatmap CSV (first row = P975, first column = P1064)
# ============================================================
csv_path = r"D:\Atanu\Atanu_Github\NaBiF4_PL_analysis\NaBiF4_PL_analysis\datas\Oct\2nd Oct NaBiF4\Percentage Modulation\csv_plot_data\heatmap_signal_data.csv"

df_heat = pd.read_csv(csv_path, header=0, index_col=0)

# ------------------------------------------------------------
# Extract power axes
# ------------------------------------------------------------
powers_975  = df_heat.columns.astype(float).to_numpy()
powers_1064 = df_heat.index.astype(float).to_numpy()

# ------------------------------------------------------------
# Extract matrix (signal)
# ------------------------------------------------------------
Q_exp = df_heat.to_numpy()

# ============================================================
# --- Plot heatmap (pixelated)
# ============================================================
fig = go.Figure()

fig.add_trace(
    go.Heatmap(
        x=powers_975,
        y=powers_1064,
        z=Q_exp,
        coloraxis="coloraxis"
    )
)

fig.update_layout(
    template=fig_template,
    xaxis_title="975 nm Power (mW)",
    yaxis_title="1064 nm Power (mW)",
    width=800,
    height=650,
    coloraxis=dict(
        colorscale="Viridis",
        cmin=np.nanmin(Q),
        cmax=np.nanmax(Q),
        showscale=True
    )
)

fig.show()



# ============================================================
# --- Save figure ---
# ============================================================
output_fig_folder = r"D:\Atanu\NaBiF4_PL_analysis\NaBiF4_PL_analysis\NaBiF4_PL_analysis\figures in paper"
os.makedirs(output_fig_folder, exist_ok=True)
out_path = os.path.join(output_fig_folder, "heatmap_experimental.png")
pio.write_image(fig, out_path, scale=4)
print("Saved figure:", out_path)
# Out:
# Saved figure: D:\Atanu\NaBiF4_PL_analysis\NaBiF4_PL_analysis\NaBiF4_PL_analysis\figures in paper\heatmap_experimental.png

# %% [markdown]
# #### STED Profile

# %% [markdown]
# ##### Quenching

# %%
# import numpy as np
# from scipy.integrate import solve_ivp
# from joblib import Parallel, delayed
# from tqdm import tqdm

# # ============================================================
# # Simulation parameters
# # ============================================================

# t_max = 300.0
# dt = 1.0
# t_eval = np.arange(0, t_max + dt, dt)

# laser_on = 25.0
# laser_off = 25.0
# period = laser_on + laser_off
# phase_shift = laser_on

# beta1 = 1/1.0
# beta2 = 1/7.0


# # ============================================================
# # Coefficients (1/ms/mW)
# # ============================================================

# k_alpha1  = 4.8
# k_alpha1p = 0.1
# k_alpha2  = 3.9
# k_alpha2p = 0.0002
# k_gamma_975 = 2.4
# k_gamma_1064 = 3.8


# # ============================================================
# # Optical parameters
# # ============================================================

# NA = 1.3

# lam_975  = 0.975
# lam_1064 = 1.064

# P975  = 20.0
# P1064 = 120.0

# w975  = 0.61 * lam_975 / NA
# w1064 = 0.61 * lam_1064 / NA


# # ============================================================
# # Pulse function
# # ============================================================

# def make_I1064_func(I_1064_peak):

#     def I1064(t):
#         phase = np.mod(t + phase_shift, period)
#         return np.where(phase < laser_on, I_1064_peak, 0.0)

#     return I1064


# # ============================================================
# # Rate equation solver
# # ============================================================

# def run_sim_emission(I_975, I_1064_peak):

#     I1064 = make_I1064_func(I_1064_peak)

#     def I975_func(t):
#         return I_975 if np.isscalar(t) else np.full_like(t, I_975)

#     def alpha1(t):
#         return k_alpha1 * I975_func(t) + k_alpha2 * I1064(t)

#     def alpha1p(t):
#         return k_alpha1p * I975_func(t) + k_alpha2p * I1064(t)

#     def gamma975(t):
#         return k_gamma_975 * I975_func(t)

#     def gamma1064(t):
#         return k_gamma_1064 * I1064(t)

#     def rate_equations(t, N):

#         N0, N1, N2 = N

#         a1 = alpha1(t)
#         a1p = alpha1p(t)
#         g1 = gamma975(t)
#         g2 = gamma1064(t)

#         dN0 = -a1 * N0 + (beta1 + g1 + g2) * N1 + beta2 * N2
#         dN1 = a1 * N0 - (a1p + beta1 + g1 + g2) * N1
#         dN2 = a1p * N1 - beta2 * N2

#         return [dN0, dN1, dN2]

#     sol = solve_ivp(
#         rate_equations,
#         [0, t_max],
#         [1, 0, 0],
#         t_eval=t_eval,
#         atol=1e-9,
#         rtol=1e-7
#     )

#     emission = beta2 * sol.y[2]

#     return np.mean(emission)


# # ============================================================
# # Radial grid
# # ============================================================

# r = np.linspace(0, 2.0, 200)


# # ============================================================
# # Power-normalized beam profiles
# # ============================================================

# # Gaussian excitation beam
# I975_profile = (2 * P975 / (np.pi * w975**2)) * np.exp(-2 * (r**2) / (w975**2))

# # STED donut (LG01) normalized
# I1064_profile = (4 * P1064 / (np.pi * w1064**2)) * (r**2 / w1064**2) * np.exp(-2 * (r**2) / (w1064**2))


# # ============================================================
# # Parallel simulation
# # ============================================================

# def compute_point(i):

#     I975 = I975_profile[i]
#     I1064 = I1064_profile[i]

#     efficiency = run_sim_emission(I975, I1064)

#     return I975 * efficiency


# emission_profile = Parallel(n_jobs=-1)(
#     delayed(compute_point)(i) for i in tqdm(range(len(r)))
# )

# emission_profile = np.array(emission_profile)


# # ============================================================
# # PSF cross section
# # ============================================================

# x_line = np.linspace(-2, 2, 400)
# r_line = np.abs(x_line)

# I975_line = np.interp(r_line, r, I975_profile)
# Emission_line = np.interp(r_line, r, emission_profile)


# # ============================================================
# # FWHM calculation
# # ============================================================

# def compute_fwhm(x, y):

#     y = y / np.max(y)

#     half = 0.5
#     indices = np.where(y >= half)[0]

#     if len(indices) < 2:
#         return np.nan

#     return x[indices[-1]] - x[indices[0]]


# FWHM_exc = compute_fwhm(x_line, I975_line)
# FWHM_em  = compute_fwhm(x_line, Emission_line)

# resolution_gain = FWHM_exc / FWHM_em

# print("\nResolution analysis")
# print("Excitation FWHM :", FWHM_exc, "µm")
# print("Emission FWHM :", FWHM_em, "µm")
# print("Resolution gain :", resolution_gain)


# # ============================================================
# # 2D maps
# # ============================================================

# extent = 2
# grid = 300

# x = np.linspace(-extent, extent, grid)
# y = np.linspace(-extent, extent, grid)

# X, Y = np.meshgrid(x, y)

# R = np.sqrt(X**2 + Y**2)

# I975_2D = (2 * P975 / (np.pi * w975**2)) * np.exp(-2 * (R**2) / (w975**2))

# I1064_2D = (4 * P1064 / (np.pi * w1064**2)) * (R**2 / w1064**2) * np.exp(-2 * (R**2) / (w1064**2))

# Emission_2D = np.interp(R, r, emission_profile)

# %%
import numpy as np

# ============================================================
# Optical parameters
# ============================================================

NA = 1.3

lam_975  = 0.975
lam_1064 = 1.064

P975  = 20
P1064 = 200.0

w975  = 0.61 * lam_975 / NA
w1064 = 0.61 * lam_1064 / NA


# ============================================================
# Rate coefficients
# ============================================================

beta2 = 1/0.2  # effective lifetime from both 975 nm and 1064 nm wavelengths
beta1 = 1/0.5  # effective lifetime from both 975 nm and 1064 nm wavelengths


# Coefficients (1/ms/mW)
k_alpha1  = 0.22
k_alpha1p = 0.23
k_alpha2  = 0.0001
k_alpha2p = 0.0002
k_gamma_975 = 0.0001
k_gamma_1064 = 0.005


# ============================================================
# Radial grid
# ============================================================

r = np.linspace(0, 2.0, 120)


# ============================================================
# Correct power-normalized beam profiles
# ============================================================

def gaussian_beam(P, w, r):
    return (2 * P / (np.pi * w**2)) * np.exp(-2 * r**2 / w**2)

def donut_beam(P, w, r):
    return (4 * P / (np.pi * w**2)) * (r**2 / w**2) * np.exp(-2 * r**2 / w**2)


# Choose beam types
I975_profile  = gaussian_beam(P975, w975, r)
I1064_profile = donut_beam(P1064, w1064, r)


# ============================================================
# Steady-state emission calculation
# ============================================================

emission_profile = []

for i in range(len(r)):

    I975  = I975_profile[i]
    I1064 = I1064_profile[i]

    alpha1  = k_alpha1 * I975 + k_alpha2 * I1064
    alpha1p = k_alpha1p * I975 + k_alpha2p * I1064

    gamma1 = k_gamma_975 * I975
    gamma2 = k_gamma_1064 * I1064

    # steady state solution

    A = alpha1p / beta2
    B = (alpha1p + beta1 + gamma1 + gamma2)

    N1 = alpha1 / (B + alpha1 + alpha1p * alpha1 / beta2)
    N2 = A * N1

    emission = beta2 * N2

    emission_profile.append(emission)

emission_profile = np.array(emission_profile)


# ============================================================
# PSF cross section
# ============================================================

x_line = np.linspace(-2, 2, 400)
r_line = np.abs(x_line)

I975_line = np.interp(r_line, r, I975_profile)
Emission_line = np.interp(r_line, r, emission_profile)


# ============================================================
# FWHM calculation
# ============================================================

def compute_fwhm(x, y):

    y = y / np.max(y)

    half = 0.5
    indices = np.where(y >= half)[0]

    if len(indices) < 2:
        return np.nan

    return x[indices[-1]] - x[indices[0]]


FWHM_exc = compute_fwhm(x_line, I975_line)
FWHM_em  = compute_fwhm(x_line, Emission_line)

resolution_gain = FWHM_exc / FWHM_em


print("\nResolution analysis")
print("Excitation FWHM :", FWHM_exc, "µm")
print("Emission FWHM :", FWHM_em, "µm")
print("Resolution gain :", resolution_gain)


# ============================================================
# 2D maps
# ============================================================

extent = 2
grid = 300

x = np.linspace(-extent, extent, grid)
y = np.linspace(-extent, extent, grid)

X, Y = np.meshgrid(x, y)

R = np.sqrt(X**2 + Y**2)

# 2D beam profiles (power normalized)

I975_2D  = (2 * P975 / (np.pi * w975**2)) * np.exp(-2 * R**2 / w975**2)

I1064_2D = (4 * P1064 / (np.pi * w1064**2)) * (R**2 / w1064**2) * np.exp(-2 * R**2 / w1064**2)

Emission_2D = np.interp(R, r, emission_profile)
# Out:
# Resolution analysis
# Excitation FWHM : 0.531328320802005 µm
# Emission FWHM : 0.6315789473684212 µm
# Resolution gain : 0.841269841269841

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots


# ============================================================
# Plot template
# ============================================================

fig_template = go.layout.Template()
fig_template.layout = {
    'template':'simple_white+presentation',
    'autosize':False,
    'width':900,
    'height':600,
    'xaxis':{'ticks':'inside','mirror':'ticks','linewidth':2.5,'showline':True},
    'yaxis':{'ticks':'inside','mirror':'ticks','linewidth':2.5,'showline':True},
    'font':{'family':'mathjax','size':24}
}


# ============================================================
# Radial beam profiles
# ============================================================

fig1 = make_subplots(rows=1,cols=3,
                     subplot_titles=[
                     "975 nm excitation",
                     "1064 nm donut",
                     "Emission"])

fig1.add_trace(go.Scatter(x=r,y=I975_profile,name="975 nm"),row=1,col=1)
fig1.add_trace(go.Scatter(x=r,y=I1064_profile,name="1064 nm donut"),row=1,col=2)
fig1.add_trace(go.Scatter(x=r,y=emission_profile,name="Emission"),row=1,col=3)

fig1.update_layout(template=fig_template)

fig1.update_xaxes(title="Radius (µm)")
fig1.update_yaxes(title="Intensity (a.u.)")

fig1.show()


# ============================================================
# PSF cross section with donut beam
# ============================================================

# Donut cross section along ±x
I1064_line = np.interp(r_line, r, I1064_profile)

fig2 = go.Figure()

fig2.add_trace(go.Scatter(
    x=x_line,
    y=I975_line,
    name="975 nm excitation"
))

fig2.add_trace(go.Scatter(
    x=x_line,
    y=I1064_line,
    name="1064 nm donut"
))

fig2.add_trace(go.Scatter(
    x=x_line,
    y=Emission_line,
    name="Emission PSF"
))

fig2.update_layout(
    template=fig_template,
    title="PSF cross-section"
)

fig2.update_xaxes(title="Position (µm)")
fig2.update_yaxes(title="Intensity (a.u.)")

fig2.show()


# ============================================================
# 2D PSF maps
# ============================================================

fig3 = make_subplots(
    rows=1,
    cols=3,
    subplot_titles=[
        "975 nm excitation",
        "1064 nm donut",
        "Emission PSF"
    ]
)

fig3.add_trace(
    go.Heatmap(z=I975_2D,x=x,y=y,coloraxis="coloraxis"),
    row=1,col=1
)

fig3.add_trace(
    go.Heatmap(z=I1064_2D,x=x,y=y,coloraxis="coloraxis"),
    row=1,col=2
)

fig3.add_trace(
    go.Heatmap(z=Emission_2D,x=x,y=y,coloraxis="coloraxis"),
    row=1,col=3
)

fig3.update_layout(
    template=fig_template,
    title="2D PSF profiles",
    coloraxis=dict(colorscale="inferno")
)

fig3.update_xaxes(title="x (µm)")
fig3.update_yaxes(title="y (µm)")

fig3.show()

# %% [markdown]
# ##### Enhancement

# %%
import numpy as np
import plotly.graph_objects as go

# ============================================================
# --- Figure Template ---
# ============================================================

fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 800,
    'height': 600,
    'xaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False,'zerolinecolor':'white'},
    'yaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False,'zerolinecolor':'white'},
    'font': {'family':'mathjax','size':30}
}

# ============================================================
# Optical parameters
# ============================================================

NA = 1.3

lam_975  = 0.975
lam_1064 = 1.064

P975  = 50
P1064 = 100.0

w975  = 0.61 * lam_975 / NA
w1064 = 0.61 * lam_1064 / NA

# ============================================================
# Rate coefficients
# ============================================================

beta2 = 1/0.2 
beta1 = 1/0.5  


# Coefficients (1/ms/mW)
k_alpha1  = 0.014
k_alpha1p = 0.016
k_alpha2  = 0.0000045
k_alpha2p = 0.000007
k_gamma_975 = 0.039
k_gamma_1064 = 0.001

# ============================================================
# Radial grid
# ============================================================

r = np.linspace(0,2,400)

# ============================================================
# Beam profiles
# ============================================================

def gaussian_beam(P,w,r):
    return (2*P/(np.pi*w**2))*np.exp(-2*r**2/w**2)

def donut_beam(P,w,r):
    return (4*P/(np.pi*w**2))*(r**2/w**2)*np.exp(-2*r**2/w**2)

# ============================================================
# Power check
# ============================================================

def check_power(I,r):

    dr = r[1]-r[0]
    power = np.sum(I * 2*np.pi*r * dr)

    return power

# ============================================================
# FWHM calculation
# ============================================================

def compute_fwhm(x,y):

    if np.max(y)==0:
        return np.nan

    y_norm = y/np.max(y)
    half = 0.5
    indices = np.where(y_norm>=half)[0]

    if len(indices)<2:
        return np.nan

    return x[indices[-1]]-x[indices[0]]


def compute_fwhm_lobe(x,y):

    if np.max(y)==0:
        return np.nan

    y_norm = y/np.max(y)

    # Take only one side (positive x → single lobe)
    mask = x > 0
    x_pos = x[mask]
    y_pos = y_norm[mask]

    indices = np.where(y_pos >= 0.5)[0]

    if len(indices) < 2:
        return np.nan

    return x_pos[indices[-1]] - x_pos[indices[0]]

# ============================================================
# Steady-state emission model
# ============================================================

def emission_model(I975,I1064):

    alpha1  = k_alpha1 * I975 + k_alpha2 * I1064
    alpha1p = k_alpha1p * I975 + k_alpha2p * I1064

    gamma1 = k_gamma_975 * I975
    gamma2 = k_gamma_1064 * I1064
    gamma  = gamma1 + gamma2

    denominator = alpha1*(1 + alpha1p/beta2) + alpha1p + beta1 + gamma

    if denominator == 0:
        return 0

    N1 = alpha1 / denominator
    N2 = (alpha1p/beta2) * N1

    emission = beta2 * N2

    return emission



# ============================================================
# Simulation
# ============================================================

def simulate_case(I975_profile,I1064_profile,label):

    emission_profile = []

    for i in range(len(r)):
        emission_profile.append(
            emission_model(I975_profile[i],I1064_profile[i])
        )

    emission_profile = np.array(emission_profile)

    # --------------------------------------------------------
    # Power check
    # --------------------------------------------------------

    power_975  = check_power(I975_profile,r)
    power_1064 = check_power(I1064_profile,r)

    print("\n",label)
    print("Integrated 975 power  :",power_975)
    print("Integrated 1064 power :",power_1064)

    # --------------------------------------------------------
    # Cross section
    # --------------------------------------------------------

    x_line = np.linspace(-2,2,500)
    r_line = np.abs(x_line)

    I975_line  = np.interp(r_line,r,I975_profile)
    I1064_line = np.interp(r_line,r,I1064_profile)
    Em_line    = np.interp(r_line,r,emission_profile)

    Beam_total = I975_line
    if power_975==0:
        Beam_total = I1064_line

    # --------------------------------------------------------
    # Normalize PL
    # --------------------------------------------------------

    # beam_max = max(np.max(I975_line), np.max(I1064_line))
    beam_max = np.max(I975_line)
    if power_975==0:
        beam_max = np.max(I1064_line)
    
    pl_max   = np.max(Em_line)

    if pl_max > 0:
        norm_factor = beam_max / pl_max
        # norm_factor = 1
        Em_scaled = Em_line * norm_factor
    else:
        norm_factor = 1
        Em_scaled = Em_line

    # --------------------------------------------------------
    # FWHM
    # --------------------------------------------------------

    # FWHM_beam = compute_fwhm(x_line,Beam_total)
    if "975 Donut" in label and np.max(I975_line) > 0:
        FWHM_beam = compute_fwhm_lobe(x_line, I975_line)
    else:
        FWHM_beam = compute_fwhm(x_line, Beam_total)

    if "975 Donut" in label and np.max(I975_line) > 0:
        FWHM_em   = compute_fwhm_lobe(x_line,Em_line)
    else:
        FWHM_em   = compute_fwhm(x_line,Em_line)
    # FWHM_em   = compute_fwhm(x_line,Em_line)

    print("Beam FWHM :",FWHM_beam)
    print("PL FWHM   :",FWHM_em)
    # print("PL normalization factor :",norm_factor)

    # --------------------------------------------------------
    # Plot
    # --------------------------------------------------------

    fig = go.Figure(layout_template=fig_template)

    if np.max(I975_line)>0:
        fig.add_trace(go.Scatter(
            x=x_line,
            y=I975_line,
            name="975 nm beam",
            showlegend = False,
        ))

    if np.max(I1064_line)>0:
        fig.add_trace(go.Scatter(
            x=x_line,
            y=I1064_line,
            name="1064 nm beam",
            showlegend = False,
        ))

    fig.add_trace(go.Scatter(
        x=x_line,
        y=Em_scaled,
        name=f"PL emission (×{norm_factor:.2e})",
        showlegend = False,
    ))

    fig.update_layout(
        title=label,
        width = 800,
        height = 650,
        xaxis_title="Position (µm)",
        # yaxis_title="Intensity"
    )
    fig.update_layout(
    margin=dict(l=100, r=40, t=60, b=80)
    )



    fig.show()

    return FWHM_beam,FWHM_em

# ============================================================
# CASE 1
# ============================================================

I975  = np.zeros_like(r)
I1064 = gaussian_beam(P1064,w1064,r)

simulate_case(I975,I1064,"1064 nm Gaussian only")

# ============================================================
# CASE 2
# ============================================================

I975  = gaussian_beam(P975,w975,r)
I1064 = np.zeros_like(r)

simulate_case(I975,I1064,"975 nm Gaussian only")

# ============================================================
# CASE 3
# ============================================================

I975  = gaussian_beam(P975,w975,r)
I1064 = gaussian_beam(P1064,w1064,r)

simulate_case(I975,I1064,"Both Gaussian beams")

# ============================================================
# CASE 4
# ============================================================

I975  = donut_beam(P975,w975,r)
I1064 = gaussian_beam(P1064,w1064,r)

simulate_case(I975,I1064,"1064 Gaussian + 975 Donut")

# ============================================================
# CASE 5
# ============================================================

I975  = gaussian_beam(P975,w975,r)
I1064 = donut_beam(P1064,w1064,r)

simulate_case(I975,I1064,"1064 Donut + 975 Gaussian")
# Out:
#  1064 nm Gaussian only
# Integrated 975 power  : 0.0
# Integrated 1064 power : 99.99663995201432
# Beam FWHM : 0.5851703406813624
# PL FWHM   : 0.4248496993987978
#  975 nm Gaussian only
# Integrated 975 power  : 49.997999257581284
# Integrated 1064 power : 0.0
# Beam FWHM : 0.5370741482965928
# PL FWHM   : 0.4889779559118239
#  Both Gaussian beams
# Integrated 975 power  : 49.997999257581284
# Integrated 1064 power : 99.99663995201432
# Beam FWHM : 0.5370741482965928
# PL FWHM   : 0.4889779559118239
#  1064 Gaussian + 975 Donut
# Integrated 975 power  : 50.00000004803877
# Integrated 1064 power : 99.99663995201432
# Beam FWHM : 0.3687374749498997
# PL FWHM   : 0.3126252505010019
#  1064 Donut + 975 Gaussian
# Integrated 975 power  : 49.997999257581284
# Integrated 1064 power : 100.00000006770809
# Beam FWHM : 0.5370741482965928
# PL FWHM   : 0.4889779559118239
# (np.float64(0.5370741482965928), np.float64(0.4889779559118239))

# %%
import numpy as np
from scipy.integrate import solve_ivp
import plotly.graph_objects as go
from joblib import Parallel, delayed
from tqdm import tqdm
from contextlib import contextmanager

# ============================================================
# tqdm + joblib
# ============================================================

@contextmanager
def tqdm_joblib(tqdm_object):
    import joblib
    class TqdmBatchCompletionCallback(joblib.parallel.BatchCompletionCallBack):
        def __call__(self, *args, **kwargs):
            tqdm_object.update(n=self.batch_size)
            return super().__call__(*args, **kwargs)
    old_callback = joblib.parallel.BatchCompletionCallBack
    joblib.parallel.BatchCompletionCallBack = TqdmBatchCompletionCallback
    try:
        yield tqdm_object
    finally:
        joblib.parallel.BatchCompletionCallBack = old_callback
        tqdm_object.close()

# ============================================================
# Figure Template
# ============================================================

fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 800,
    'height': 650,
    'xaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False},
    'yaxis': {'ticks':'inside','mirror':'ticks','linewidth':2.5,'tickwidth':2.5,'ticklen':4,'showline':True,'showgrid':False},
    'font': {'family':'mathjax','size':30}
}

# ============================================================
# Time parameters
# ============================================================

t_max = 300.0
dt = 1.0
t_eval = np.arange(0, t_max + dt, dt)

laser_on = 25.0
laser_off = 25.0
period = laser_on + laser_off
phase_shift = laser_on

pulse_index = 4

# ============================================================
# Optical parameters
# ============================================================

NA = 1.3
lam_975  = 0.975
lam_1064 = 1.064

P975  = 50
P1064 = 100.0

w975  = 0.61 * lam_975 / NA
w1064 = 0.61 * lam_1064 / NA

# ============================================================
# Rate coefficients
# ============================================================

beta2 = 1/0.2 
beta1 = 1/0.5  

k_alpha1  = 0.014
k_alpha1p = 0.016
k_alpha2  = 0.0000045
k_alpha2p = 0.000007
k_gamma_975 = 0.039
k_gamma_1064 = 0.001

# ============================================================
# Grid
# ============================================================

r = np.linspace(0,2,400)

# ============================================================
# Beams
# ============================================================

def gaussian_beam(P,w,r):
    return (2*P/(np.pi*w**2))*np.exp(-2*r**2/w**2)

def donut_beam(P,w,r):
    return (4*P/(np.pi*w**2))*(r**2/w**2)*np.exp(-2*r**2/w**2)

# ============================================================
# Pulse
# ============================================================

def make_I1064_func(I_1064_peak):
    def I1064(t):
        phase = np.mod(t + phase_shift, period)
        return I_1064_peak if phase < laser_on else 0.0
    return I1064

# ============================================================
# Core physics
# ============================================================

def compute_PL_and_quenching(I975, I1064_peak):

    if I1064_peak < 5:
        alpha1  = k_alpha1 * I975
        alpha1p = k_alpha1p * I975
        gamma   = k_gamma_975 * I975

        denom = alpha1*(1 + alpha1p/beta2) + alpha1p + beta1 + gamma

        if denom == 0:
            return 0, 0

        N1 = alpha1 / denom
        N2 = (alpha1p/beta2) * N1

        PL = beta2 * N2
        return PL, 0

    I1064 = make_I1064_func(I1064_peak)

    def rate_equations(t, N):
        N0, N1, N2 = N

        alpha1  = k_alpha1 * I975 + k_alpha2 * I1064(t)
        alpha1p = k_alpha1p * I975 + k_alpha2p * I1064(t)

        gamma1 = k_gamma_975 * I975
        gamma2 = k_gamma_1064 * I1064(t)

        dN0 = -alpha1*N0 + (beta1+gamma1+gamma2)*N1 + beta2*N2
        dN1 = alpha1*N0 - (alpha1p+beta1+gamma1+gamma2)*N1
        dN2 = alpha1p*N1 - beta2*N2

        return [dN0, dN1, dN2]

    sol = solve_ivp(rate_equations, [0, t_max], [1,0,0],
                    t_eval=t_eval, atol=1e-8, rtol=1e-6)

    emission = beta2 * sol.y[2]
    t = sol.t

    I1064_t = np.array([I1064(ti) for ti in t])

    on_indices = np.where((I1064_t[:-1]==0) & (I1064_t[1:]>0))[0]

    if len(on_indices) == 0 or pulse_index >= len(on_indices):
        return emission[-1], 0

    idx_on  = on_indices[pulse_index] + 1
    idx_off = idx_on + np.where(I1064_t[idx_on:] == 0)[0][0]

    start_mask = (t >= t[idx_on]) & (t < t[idx_on] + dt)
    end_mask   = (t >= t[idx_off] - dt) & (t < t[idx_off])

    PL_start = emission[start_mask].mean()
    PL_end   = emission[end_mask].mean()

    quenching = (PL_start - PL_end) / PL_start * 100

    return PL_end, quenching

# ============================================================
# FWHM FUNCTIONS
# ============================================================

def compute_fwhm(x,y):
    if np.max(y) <= 0:
        return np.nan
    y_norm = y/np.max(y)
    idx = np.where(y_norm >= 0.5)[0]
    if len(idx) < 2:
        return np.nan
    return x[idx[-1]] - x[idx[0]]

def compute_fwhm_lobe(x,y):
    if np.max(y) <= 0:
        return np.nan
    y_norm = y / np.max(y)
    mask = x > 0   # 👉 ignore central null
    x_pos = x[mask]
    y_pos = y_norm[mask]
    idx = np.where(y_pos >= 0.5)[0]
    if len(idx) < 2:
        return np.nan
    return x_pos[idx[-1]] - x_pos[idx[0]]

# ============================================================
# Simulation
# ============================================================

def simulate_case(I975_profile,I1064_profile,label, use_lobe_fwhm=False):

    print("\nRunning:", label)

    with tqdm_joblib(tqdm(total=len(r), desc="Computing PL + Quenching")):
        results = Parallel(n_jobs=-1)(
            delayed(compute_PL_and_quenching)(I975_profile[i], I1064_profile[i])
            for i in range(len(r))
        )

    results = np.array(results)

    PL_profile = results[:,0]
    quenching_profile = results[:,1]

    print("\n--- Detailed Output ---")
    for i in range(len(r)):
        print(f"r = {r[i]:.4f} µm | I975 = {I975_profile[i]:.4f} | I1064 = {I1064_profile[i]:.4f} → Quenching = {quenching_profile[i]:.2f} %")

    # ============================================================
    # Interpolation
    # ============================================================

    x_line = np.linspace(-2,2,500)
    r_line = np.abs(x_line)

    I975_line  = np.interp(r_line,r,I975_profile)
    I1064_line = np.interp(r_line,r,I1064_profile)
    PL_line    = np.interp(r_line,r,PL_profile)
    quench_line = np.interp(r_line,r,quenching_profile)

    # ============================================================
    # FWHM
    # ============================================================

    if use_lobe_fwhm:
        FWHM_beam = compute_fwhm_lobe(x_line, I975_line)
        FWHM_PL   = compute_fwhm_lobe(x_line, PL_line)
    else:
        Beam_total = I975_line if np.max(I975_line)>0 else I1064_line
        FWHM_beam = compute_fwhm(x_line, Beam_total)
        FWHM_PL   = compute_fwhm(x_line, PL_line)

    print("Beam FWHM :",FWHM_beam)
    print("PL FWHM   :",FWHM_PL)

    # ============================================================
    # Plot
    # ============================================================

    fig = go.Figure(layout_template=fig_template)

    fig.add_trace(go.Scatter(x=x_line, y=I975_line, name="975 nm"))
    fig.add_trace(go.Scatter(x=x_line, y=I1064_line, name="1064 nm"))
    fig.add_trace(go.Scatter(x=x_line, y=PL_line, name="PL"))

    fig.add_trace(go.Scatter(
        x=x_line,
        y=quench_line,
        name="Quenching (%)",
        yaxis="y2"
    ))

    fig.update_layout(
        title=label,
        xaxis_title="Position (µm)",
        yaxis_title="Intensity",
        yaxis2=dict(title="Quenching (%)", overlaying='y', side='right'),
        legend=dict(
            orientation="h",
            yanchor="bottom",
            y=1.05,
            xanchor="center",
            x=0.5
        ),
        margin=dict(l=110, r=80, t=100, b=80),
    )

    fig.show()

# ============================================================
# RUN
# ============================================================

simulate_case(np.zeros_like(r), gaussian_beam(P1064,w1064,r), "1064 Gaussian only")

simulate_case(gaussian_beam(P975,w975,r), np.zeros_like(r), "975 Gaussian only")

simulate_case(
    gaussian_beam(P975,w975,r),
    gaussian_beam(P1064,w1064,r),
    "Both Gaussian"
)

simulate_case(
    donut_beam(P975,w975,r),
    gaussian_beam(P1064,w1064,r),
    "975 Donut + 1064 Gaussian",
    use_lobe_fwhm=True
)

simulate_case(
    gaussian_beam(P975,w975,r),
    donut_beam(P1064,w1064,r),
    "1064 Donut + 975 Gaussian"
)
# Out:
# Running: 1064 Gaussian only
# Computing PL + Quenching: 100%|██████████████████████████████████████████████████████| 400/400 [00:08<00:00, 45.74it/s]
# --- Detailed Output ---
# r = 0.0000 µm | I975 = 0.0000 | I1064 = 255.4018 → Quenching = -24393.48 %
# r = 0.0050 µm | I975 = 0.0000 | I1064 = 255.3503 → Quenching = -10893.01 %
# r = 0.0100 µm | I975 = 0.0000 | I1064 = 255.1959 → Quenching = -2169.11 %
# r = 0.0150 µm | I975 = 0.0000 | I1064 = 254.9388 → Quenching = -2307.85 %
# r = 0.0201 µm | I975 = 0.0000 | I1064 = 254.5793 → Quenching = -23622.75 %
# r = 0.0251 µm | I975 = 0.0000 | I1064 = 254.1178 → Quenching = -24649.90 %
# r = 0.0301 µm | I975 = 0.0000 | I1064 = 253.5549 → Quenching = -4868.77 %
# r = 0.0351 µm | I975 = 0.0000 | I1064 = 252.8912 → Quenching = -23380.35 %
# r = 0.0401 µm | I975 = 0.0000 | I1064 = 252.1277 → Quenching = -8932.28 %
# r = 0.0451 µm | I975 = 0.0000 | I1064 = 251.2651 → Quenching = -3910.97 %
# ...

# %%
import numpy as np
import plotly.graph_objects as go
from scipy.optimize import curve_fit

# ============================================================
# Power ranges
# ============================================================

P975_range  = np.geomspace(0.1, 30, 50)
P1064_range = np.geomspace(0.1, 500, 50)

# Fix one while varying the other
P975_fixed  = 0
P1064_fixed = 0

# ============================================================
# Convert power → intensity (use beam center r=0)
# ============================================================

def I_center_gaussian(P, w):
    return (2 * P) / (np.pi * w**2)

# ============================================================
# Emission vs P975 (1064 fixed)
# ============================================================

em_vs_975 = []

for p in P975_range:
    I975  = I_center_gaussian(p, w975)
    I1064 = I_center_gaussian(P1064_fixed, w1064)

    em_vs_975.append(emission_model(I975, I1064))

em_vs_975 = np.array(em_vs_975)

# ============================================================
# Emission vs P1064 (975 fixed)
# ============================================================

em_vs_1064 = []

for p in P1064_range:
    I975  = I_center_gaussian(P975_fixed, w975)
    I1064 = I_center_gaussian(p, w1064)

    em_vs_1064.append(emission_model(I975, I1064))

em_vs_1064 = np.array(em_vs_1064)

# ============================================================
# Power law with offset
# ============================================================

def power_law(x, A, n, C):
    return A * (x ** n) + C

# ============================================================
# Avoid zero (important for power law stability)
# ============================================================

mask_975 = P975_range > 0
mask_1064 = P1064_range > 0

x975 = P975_range[mask_975]
y975 = em_vs_975[mask_975]

x1064 = P1064_range[mask_1064]
y1064 = em_vs_1064[mask_1064]

# ============================================================
# Fit: Emission vs P975
# ============================================================

popt_975, _ = curve_fit(
    power_law,
    x975,
    y975,
    p0=[1, 1, 0],       # initial guess
    maxfev=10000
)

A_975, n_975, C_975 = popt_975

fit_975 = power_law(P975_range, A_975, n_975, C_975)

# ============================================================
# Fit: Emission vs P1064
# ============================================================

popt_1064, _ = curve_fit(
    power_law,
    x1064,
    y1064,
    p0=[1, 1, 0],
    maxfev=10000
)

A_1064, n_1064, C_1064 = popt_1064

fit_1064 = power_law(P1064_range, A_1064, n_1064, C_1064)

# ============================================================
# Plot
# ============================================================

fig = go.Figure(layout_template=fig_template)
fig1 = go.Figure(layout_template=fig_template)

# --- Data ---
fig.add_trace(go.Scatter(
    x=P975_range,
    y=em_vs_975,
    name="Data",
    mode="markers",
    showlegend = False,
))

fig1.add_trace(go.Scatter(
    x=P1064_range,
    y=em_vs_1064,
    name="Data",
    mode="markers",
    showlegend = False,
))

# --- Fit ---
fig.add_trace(go.Scatter(
    x=P975_range,
    y=fit_975,
    name=f"Fit (n = {n_975:.2f})",
    mode="lines",
    line=dict(dash='dash'),
    showlegend = False,
))

fig1.add_trace(go.Scatter(
    x=P1064_range,
    y=fit_1064,
    name=f"Fit (n = {n_1064:.2f})",
    mode="lines",
    line=dict(dash='dash'),
    showlegend = False,
))

# ============================================================
# Layout
# ============================================================

fig.update_layout(
    template=fig_template,
    width = 800,
    height = 650,
    title=f"Emission vs P975 (n = {n_975:.2f})",
    xaxis_title="Power (mW)",
    # yaxis_title="Emission (a.u.)"
)

fig1.update_layout(
    template=fig_template,
    width = 800,
    height = 650,
    title=f"Emission vs P1064 (n = {n_1064:.2f})",
    xaxis_title="Power (mW)",
    # yaxis_title="Emission (a.u.)"
)

fig.update_layout(
    margin=dict(l=100, r=40, t=60, b=80)
)

fig1.update_layout(
    margin=dict(l=100, r=40, t=60, b=80)
)

fig.show()
fig1.show()

# ============================================================
# Print fit parameters
# ============================================================

print("=== Fit vs P975 ===")
print(f"A = {A_975:.4e}, n = {n_975:.4f}, C = {C_975:.4e}")

print("\n=== Fit vs P1064 ===")
print(f"A = {A_1064:.4e}, n = {n_1064:.4f}, C = {C_1064:.4e}")
# Out:
# === Fit vs P975 ===
# A = 2.4294e-03, n = 1.3260, C = -1.4170e-03
#
# === Fit vs P1064 ===
# A = 3.9218e-10, n = 1.7058, C = -1.8626e-08

# %% [markdown]
# ### Observations

# %% [markdown]
# 1. With fixed **high** 975 nm power, the quenching percentage is **increasing** with the power of the 1064 nm wavelength.
# 2. With fixed **low** 975 nm power, the quenching percentage is **decreasing** with the power of the 1064 nm wavelength.
# 3. With fixed **low** or **high** power of 1064 nm wavelength, the nature of the quenching percentage curve with 975 nm powers is **unchanged**, except that the PL enhancement is increasing with the increment of 1064 nm power.
#
# 4. The PL emission is controllable with the varied 975 nm powers, either increasing or decreasing, similar to the experimental observation.
